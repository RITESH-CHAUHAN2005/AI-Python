# %% [markdown]
# <a href="https://colab.research.google.com/github/RITESH-CHAUHAN2005/AI-Python/blob/main/Session_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Agenda
#Functions of Data Structure
#Panda Library

# %%
a = 1,2,5,4
a
# Out:
# (1, 2, 5, 4)

# %%
lis = [1,2,3,4,5]

# %%
lis
# Out:
# [1, 2, 3, 4, 5]

# %%
lis.append(1521)

# %%
lis
# Out:
# [1, 2, 3, 4, 5, 1521]

# %%
lis.extend([151,9,4581,56,5694,32,135,565,62])
lis
# Out:
# [1, 2, 3, 4, 5, 1521, 151, 9, 4581, 56, 5694, 32, 135, 565, 62]

# %%
dic = {1: "USA",
       2:"GERMANY",
       3:"NETHERLAND"

}
dic
# Out:
# {1: 'USA', 2: 'GERMANY', 3: 'NETHERLAND'}

# %%
dic.values()
# Out:
# dict_values(['USA', 'GERMANY', 'NETHERLAND'])

# %%
dic.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
#Pandas
import pandas as pd

# The correct function is read_excel, not read_xlsx
df = pd.read_excel("/content/BPIT AI Batch-1.xlsx")
df.head()
# Out:
#   *Enrollment No   *Password                *Name
# 0   SIC202506140  ClubSIC882         Bhumika Suri
# 1   SIC202506688  ClubSIC883                Gagan
# 2   SIC202506066  ClubSIC884   Govind Shreelochan
# 3   SIC202506105  ClubSIC885          Arnav Anand
# 4   SIC202506056  ClubSIC886  Jayant Mohan Mishra
